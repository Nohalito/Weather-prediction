# %%
import os

IGNORE = {'.git', '__pycache__'}

def print_tree(startpath, prefix=""):
    """
    Quick function to print our repositorie tree
    <3 ChatGPT for this one
    (`tree -I ".git|__pycache__"` doesn't work on my terminal, I guess window is at cause)
    """
    
    # List all items except ignored ones
    items = [i for i in os.listdir(startpath) if i not in IGNORE]
    
    # Separate files and directories
    files = sorted([i for i in items if os.path.isfile(os.path.join(startpath, i))])
    dirs = sorted([i for i in items if os.path.isdir(os.path.join(startpath, i))])
    
    # Combine files first, then directories
    sorted_items = files + dirs
    
    for idx, item in enumerate(sorted_items):
        path = os.path.join(startpath, item)
        connector = "└── " if idx == len(sorted_items) - 1 else "├── "
        print(prefix + connector + item)
        if os.path.isdir(path):
            extension = "    " if idx == len(sorted_items) - 1 else "│   "
            print_tree(path, prefix + extension)

# Usage: replace with your local repo path
print_tree("my/path/that/contain/personal/informations/so/I/hided/it")
# Out:
# ├── .gitignore
# ├── MULLATOR.jpg
# ├── Q_descriptif_champs_RR-T-Vent.txt
# ├── Q_descriptif_champs_autres-parametres.txt
# ├── README.md
# ├── instruction.txt
# ├── repo_tree.ipynb
# ├── requirements.txt
# ├── datasets
# │   ├── midway
# │   │   └── cross_section_features.csv
# │   ├── processed
# │   │   ├── cross_section_2013-2023.csv
# │   │   └── time_series_2013-2023.csv
# │   └── raw
# │       ├── elec_consumption.csv
# │       └── weather_base_df.csv
# ├── notebooks
# │   ├── 01_Download_raw_data_Noa.ipynb
# │   ├── 02_Data_processing_Noa.ipynb
# │   ├── 03.1_Modeling_Diallo.ipynb
# │   └── 03.2_Modeling_Paligwende.ipynb
# ├── report
# │   ├── Al-Afia_Auguste_Boimond_Diallo_Ouedraogo.aux
# │   ├── Al-Afia_Auguste_Boimond_Diallo_Ouedraogo.log
# │   ├── Al-Afia_Auguste_Boimond_Diallo_Ouedraogo.out
# │   ├── Al-Afia_Auguste_Boimond_Diallo_Ouedraogo.pdf
# │   ├── Al-Afia_Auguste_Boimond_Diallo_Ouedraogo.synctex.gz
# │   ├── Al-Afia_Auguste_Boimond_Diallo_Ouedraogo.tex
# │   ├── Al-Afia_Auguste_Boimond_Diallo_Ouedraogo.toc
# │   └── assets
# │       └── amse_logo_couleur_h600.png
# └── results
#     ├── figures
#     │   ├── Diallo_S1_IC_bootstrap_graph.png
#     │   ├── Diallo_S1_Q10_observed_vs_predicted_GAM.png
#     │   ├── Diallo_S1_Q12_selected_predictions_scatter.png
#     │   ├── Diallo_S2_Q10_forecast_plot.png
#     │   ├── Diallo_S2_Q11_RMSE_comparison.png
#     │   ├── Diallo_S2_Q11_errors_SARIMA.png
#     │   ├── Diallo_S2_Q12_selected_forecasts_plot.png
#     │   ├── Diallo_S2_SARIMA_IC_graph.png
#     │   ├── Diallo_SARIMA_illustration.png
#     │   ├── Noa_Ramzi_pair_plot.png
#     │   ├── Paligwende_comparison_plots.png
#     │   ├── Paligwende_selected_prediction_energy.png
#     │   └── Paligwende_selected_prediction_temp.png
#     ├── forecasts
#     ├── logs
#     │   ├── Diallo_S1_Q8_OLS_summary.txt
#     │   └── Diallo_S2_Q9_SARIMA_summary.txt
#     ├── models
#     └── tables
#         ├── Diallo_S1_Q10_predictions_holdout.csv
#         ├── Diallo_S1_Q11_CV_GAM.csv
#         ├── Diallo_S1_Q12_selected_predictions.csv
#         ├── Diallo_S1_Q13_prediction_intervals_bootstrap.csv
#         ├── Diallo_S1_Q8_performance.csv
#         ├── Diallo_S1_Q9_model_comparison_holdout.csv
#         ├── Diallo_S2_Q10_forecasts_holdout.csv
#         ├── Diallo_S2_Q11_time_series_cv.csv
#         ├── Diallo_S2_Q12_selected_forecasts.csv
#         ├── Diallo_S2_Q13_SARIMA_confidence_intervals.csv
#         └── Diallo_S2_Q9_model_comparison_holdout.csv
